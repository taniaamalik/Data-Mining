# %% [markdown]
# # Analisis Cluster Spasial Tingkat Kerawanan Corona Virus Disease 2019

# %% [markdown]
# Anggota Kelompok :
#
# Erlina Rohmawati (175150201111045)
#
# Tania Malik Iryana (175150201111053)
#
# Alvina Eka Damayanti (175150201111056)
#
# Jeowandha Ria Wiyani (175150207111029)
#
# Sulthon Akhdan Ghali (175150200111065)
#
# Karina Amadea (175150201111017)
#
# Annisa Nuri Nabila (175150200111068)
#
# M. Lavy Aunil Malik El Harisy (175150207111020)

# %% [markdown]
# # Latar Belakang
# Corona Virus Disease merupakan suatu penyakit berskala global (WHO). Penyebaran virus ini secara global sudah semakin meluas. Sebanyak 152 negara telah mengkonfirmasi terjangkit virus tersebut. Sementara itu, jumlah kasus virus corona sudah mencapai angka 197.168 kasus.
#
# Virus corona sangat mudah menempel pada tubuh manusia, sehingga ini memungkinkan virus ini memiliki kemampuan menginfeksi lebih baik dan mampu menyebar lebih cepat daripada virus lainnya.
#
# Para pakar menyebutkan beberapa sebab jumlah kasus yang terus menerus meningkat antara lain karena minimnya informasi lokasi penderita dan kuantitas dari pemeriksaan penderita, sikap masyarakat yang kurang peduli untuk meminimalkan kontak satu sama lain, dan juga minimnya informasi lokasi yang harus dihindari oleh masyarakat.
#
# Permasalahan diatas merupakan dasar untuk penulis berusaha memberikan solusi yang solutif dan juga dapat diimplementasikan dengan mudah serta efisien. Penulis akan melakukan analisis clustering spasial terhadap tingkat kerawanan corona virus di Indonesia.
#
# Analisis cluster seringkali ditemui dalam kehidupan sehari-hari, baik yang terkait dengan bidang sosial, bidang kesehatan sampai pada bidang klimatologi. Analisis cluster adalah salah satu analisis peubah ganda yang digunakan untuk mengelompokan objek-objek menjadi beberapa kelompok berdasarkan kemiripan variabel-variabel yang diamati, sehingga diperoleh kemiripan objek dalam kelompok yang sama dibandingkan antar objek dari kelompok yang berbeda. Konsep dari analisis cluster cukup luas sehingga dapat diimplementasikan dan diaplikasikan dalam berbagai bidang
#
# Penelitian terdahulu yang pernah dilakukan adalah perbandingan hasil analisis cluster dengan menggunakan metode single linkage dan metode k-means (perusahaan di Kutai Barat berdasarkan tingkat pencemaran udara) yang dilakukan oleh Goreti tahun (2015).
#
# # Tujuan
# -	Membangun sistem analisis cluster dengan metode Single Linkage, Average Linkage dan metode Ward
# -	Membandingkan kinerja Single Linkage, Complete Linkage, Average Linkage, Weighted Linkage dan metode Ward jika ditinjau dari hasil clustering yang dilakukan terhadap 35 provinsi yang telah terjangkit virus corona
#
#
# # Manfaat
# Dengan adanya sistem analisis clustering spasial terhadap tingkat kerawanan corona virus di Indonesia akan membantu memberikan pandangan kepada masyarakat serta pemerintah untuk lebih waspada dan bertindak lebih lanjut.
#
# Sistem akan membantu memberikan informasi lebih detail mengenai hubungan peningkatan kerawanan corona virus di Indonesia dengan kepadatan penduduk, mobilitas penduduk, kualitas udara, dan kesehatan penduduk di beberapa provinsi dengan melakukan analisis cluster spasial menggunakan metode linkage.
#
# # Metode Penyelesaian
# Penulis menggunakan beberapa metode penyelesaian agar dapat membandingkan metode terbaik yang dapat menyelesaikan permasalahan dengan lebih efisien. Metode yang digunakan antara lain :
# - Single Linkage : Metode ini didasarkan pada jarak minimum. Dimulai dengan dua obyek yang dipisahkan dengan jarak paling pendek maka keduanya akan ditempatkan pada klaster pertama, dan seterusnya. Metode ini dikenal pula dengan nama pendekatan tetangga terdekat.
# - Complete Linkage : Metode pautan lengkap (complete linkage) didasarkan pada jarak maksimum
# - Average Linkage : Dasarnya adalah jarak rata-rata antar observasi. pengelompokan dimulai dari tengan atau pasangan observasi dengan jarak paling mendekati jarak rata-rata.
# - Weighted Linkage :
# - Metode Ward : Jarak antara dua cluster dalam metode ini berdasarkan total sum of square dua cluster pada masing-masing variabel.

# %% [markdown]
# # Dataset
# Berdasarkan dataset yang penulis temukan pada :
#
# Sistem akan menggunakan beberapa parameter yaitu :
# - Parameter Jumlah Penduduk
# - Parameter Kepadatan Penduduk
# - Parameter Kualitas Udara
# - Parameter Jumlah Penduduk Lanjut Usia
# - Parameter Jumlah Penumpang Pesawat
#
# # Teori Pendukung
# Pada penelitian sebelumnya telah dibahas mengenai Perbandinan Metode Clustering Menggunakan Metode Single Linkage dan K - MEANS Pada Pengelompokan Dokumen. Penelitian tersebut di lakukan oleh Rendy Handoyo dan teman-temannya pada tahun 2014. Pada penelitian itu dihasilkan sebuah kesimpulan bahwa metode Single Linkage memiliki performansi yang lebih baik dibandingkan dengan
# metode K-means. Metode pengujian yang digunakan untuk mengukur kualitas cluster adalah Silhouette Coefficient dan Purity. Nilai Silhouette Coefficient Single Linkage selalu lebih unggul dibandingkan dengan K-Means. Pertambahan jumlah dokumen membuat nilai Silhouette Coefficient single linkage semakin kecil sedangkan K-means terkadang menghasilkan nilai yang negatif. Untuk nilai Purity , Single Linkage selalu bernilai 1 sedangkan K-Means tidak pernah bernilai 1. Hasil pertambahan jumlah cluster dan jumlah dokumen memberikan pengaruh terhadap nilai Silhouette Coefficient dan Purity . Hal ini berarti single linkage selalu menghasilkan dokumen yang sama, sedangkan K-means masih bercampur dengan dokumen yang lain.
#
# Pada penelitian lain, yang berjudul Analisa Perbandingan Clustering Metode Manual Dan Metode Single Linkage Untuk Menentukan Kinerja Agent Pada Call Centre Berbasis Asterisk For Java yang dikerjakan oleh Nur Rosyid Mubtada'i pada tahun 2011, dijelaskan bahwa Single Linkage membutuhkan waktu eksekusi yang relatif cepat yaitu sebesar 184.7 ms, karena dalam proses pembentukan cluster tidak perlu melakukan pengecekan berulang-ulang terhadap standarisasi parameter. Tetapi keakuratan dalam pembentukan cluster kurang. Sedangkan jika menggunakan metode manual, kelebihannya yaitu akurat dalam pembentukan cluster, tetapi waktu eksekusinya cukup lama.

# %% [markdown]
# # Faktor Covid-19 Di Indonesia

# %%
# Libraries
import pandas as pd
# %matplotlib notebook
from matplotlib import pyplot as plt
from scipy.cluster import hierarchy
import numpy as np
 
# Data set
# url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
url = 'D:\SMSTR 6\DATMIN\PROJEK AKHIR\dataset_normalized\dataset_normalized.csv'
df = pd.read_csv(url)
df = df.set_index('model')
del df.index.name
 
# Calculate the distance between each sample
Z = hierarchy.linkage(df, 'ward')
#    single
#    complete
#    average
#    weighted
#    ward
 
# Orientation of the dendrogram
plt.figure(figsize=(10, 7))
hierarchy.dendrogram(Z, orientation="right", labels=df.index)
plt.title("Faktor Covid Dendogram : Ward Lingkage")
plt.show()
# or
# hierarchy.dendrogram(Z, orientation="left", labels=df.index)
# Out:
# <img src="data:image/png;base64,..." width="999.2593298494784">

# %% [markdown]
# # Kasus Covid-19 Di Indonesia

# %%
# Libraries
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster import hierarchy
import numpy as np
 
# Data set
# url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
url = 'D:\SMSTR 6\DATMIN\PROJEK AKHIR\Kasus per provinsi\Kasus per provinsi.csv'
df = pd.read_csv(url)
df = df.set_index('Provinsi')
del df.index.name
 
# Calculate the distance between each sample
Z = hierarchy.linkage(df, 'weighted')
#    single
#    complete
#    average
#    weighted
#    ward
 
# Orientation of the dendrogram
plt.figure(figsize=(10, 7))
# plt.figure(figsize=(10, 7))
hierarchy.dendrogram(Z, orientation="right", labels=df.index)
plt.title("Kasus Covid Dendogram : Weighted Lingkage")
plt.show()
# or
# hierarchy.dendrogram(Z, orientation="left", labels=df.index)

# %% [markdown]
# # 1. Single Linkage

# %% [markdown]
# ![1%20Faktor%20Single%20Clustering.png](attachment:1%20Faktor%20Single%20Clustering.png)

# %% [markdown]
# Clustering Faktor Covid-19 : Single Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten
#
# Cluster 3 : Jawa Timur, Jawa Tengah, Jawa Barat
#
# Cluster 4 : Jambi, Kalimantan Tengah, Papua, Kep. Riau, Papua Barat, Riau, Nusa Tenggara Timur, Nusa Tenggara Barat, Kalimantan Selatan, Sumatera Barat, Kalimantan Barat, Kep. Bangka Belitung, Sulawesi Barat, Sulawesi Tenggara, Maluku Utara, Kalimantan Utara, Aceh, Sumatera Selatan, Gorontalo, Bengkulu, Sulawesi Tengah, Maluku, Lampung, Sumatera Utara, Kalimantan Timur, Bali, Sulawesi Selatan, Sulawesi Utara, DI Yogyakarta

# %% [markdown]
# ![1%20Kasus%20Single%20Clustering.png](attachment:1%20Kasus%20Single%20Clustering.png)

# %% [markdown]
# Clustering Kasus Covid-19 : Single Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Jawa Tengah
#
# Cluster 3 : Papua, Sumatera Barat, Kalimantan Selatan, Kalimantan Timur, Sumatera Selatan, Kalimantan Tengah, Bali, Nusa Tenggara Barat, Kalimantan Utara, DI Yogyakarta, Sumatera Utara, Bangka Belitung, Maluku, Nusa Tenggara Timur, Bengkulu, Aceh, Gorontalo, Riau, Sulawesi Tenggara, Lampung, Sulawesi Tengah, Sulawesi Barat, Maluku Utara, Papua Barat, Sulawesi Utara, Jambi, Kalimantan Barat, Kepulauan Riau, Banten, Sulawesi Selatan
#
# Cluster 4 : Jawa Timur, Jawa Barat

# %% [markdown]
# # 2. Complete Linkage

# %% [markdown]
# ![2%20Faktor%20Complete%20Clustering.png](attachment:2%20Faktor%20Complete%20Clustering.png)

# %% [markdown]
# Clustering Faktor Covid-19 : Complete Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Jawa Timur, Jawa Tengah, Jawa Barat, Banten
#
# Cluster 3 : Papua, Kep. Riau, Papua Barat, Riau, Jambi, Kalimantan Tengah, Sulawesi Barat, Sulawesi Tenggara, Maluku Utara, Kalimantan Utara, Aceh, Gorontalo, Bengkulu, Sulawesi Tengah, Lampung, Sumatera Selatan, Sumatera Utara, Kalimantan Timur, Nusa Tenggara Timur, Nusa Tenggara Barat, Kalimantan Selatan, Sumatera Barat, Kalimantan Barat, Kep. Bangka Belitung, Maluku
#
# Cluster 4 : Bali, Sulawesi Selatan, Sulawesi Utara, DI Yogyakarta

# %% [markdown]
# ![2%20Kasus%20Complete%20Clustering.png](attachment:2%20Kasus%20Complete%20Clustering.png)

# %% [markdown]
# Clustering Kasus Covid-19 : Complete Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 :Banten, Sulawesi Selatan, Jawa Tengah, Jawa Timur, Jawa Barat
#
# Cluster 3 : Kalimantan Timur, Sumatera Selatan, Kalimantan Tengah, Kalimantan Utara, DI Yogyakarta, Sumatera Utara, Papua, Sumatera Barat, Kalimantan Selatan, Bali, Nusa Tenggara Barat
#
# Cluster 4 : Maluku Utara, Papua Barat, Sulawesi Utara, Jambi, Sulawesi Barat, Riau, Sulawesi Tenggara, Lampung, Sulawesi Tengah, Kalimantan Barat, Kepulauan Riau, Nusa Tenggara Timur, Bengkulu, Aceh, Gorontalo, Bangka Belitung, Maluku

# %% [markdown]
# # 3. Average Linkage

# %% [markdown]
# ![3%20Faktor%20Average%20Clustering.png](attachment:3%20Faktor%20Average%20Clustering.png)

# %% [markdown]
# Clustering Faktor Covid-19 : Average Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten
#
# Cluster 3 : Lampung, Sumatera Utara, Kalimantan Timur, Sulawesi Barat, Sulawesi Tenggara, Maluku Utara, Kalimantan Utara, Aceh, Gorontalo, Bengkulu, Sulawesi Tengah, Nusa Tenggara Timur, Nusa Tenggara Barat, Kalimantan Selatan, Sumatera Barat, Kalimantan Barat, Kep. Bangka Belitung, Sumatera Selatan, Maluku, Papua, Kep. Riau, Papua Barat, Riau, Jambi, Kalimantan Tengah, Bali, Sulawesi Selatan, Sulawesi Utara, DI Yogyakarta
#
# Cluster 4 : Jawa Timur, Jawa Tengah, Jawa Barat

# %% [markdown]
# ![3%20Kasus%20Average%20Clustering.png](attachment:3%20Kasus%20Average%20Clustering.png)

# %% [markdown]
# Clustering Kasus Covid-19 : Average Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten, Sulawesi Selatan, Jawa Tengah
#
# Cluster 3 : Kalimantan Timur, Sumatera Selatan, Kalimantan Tengah, Kalimantan Utara, DI Yogyakarta, Sumatera Utara, Papua, Sumatera Barat, Kalimantan Selatan, Bali, Nusa Tenggara Barat, Riau, Sulawesi Tenggara, Lampung, Sulawesi Tengah, Sulawesi Barat, Maluku Utara, Papua Barat, Sulawesi Utara, Jambi, Kalimantan Barat, Kepulauan Riau, Nusa Tenggara Timur, Bengkulu, Aceh, Gorontalo, Bangka Belitung, Maluku
#
# Cluster 4 : Jawa Timur, Jawa Barat

# %% [markdown]
# # 4. Weighted Linkage

# %% [markdown]
# ![4%20Faktor%20Weighted%20Clustering.png](attachment:4%20Faktor%20Weighted%20Clustering.png)

# %% [markdown]
# Clustering Faktor Covid-19 : Weighted Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten
#
# Cluster 3 : Jawa Timur, Jawa Tengah, Jawa Barat
#
# Cluster 4 : Sulawesi Barat, Sulawesi Tenggara, Maluku Utara, Kalimantan Utara, Aceh, Nusa Tenggara Timur, Nusa Tenggara Barat, Kalimantan Selatan, Sumatera Barat, Kalimantan Barat, Kep. Bangka Belitung, Gorontalo, Bengkulu, Sulawesi Tengah, Papua, Kep. Riau, Papua Barat, Riau, Jambi, Kalimantan Tengah, lampung, Sumatera Selatan, Sumatera Utara, Maluku, Kalimantan Timur, Bali, Sulawesi Selatan, Sulawesi Utara, DI Yogyakarta

# %% [markdown]
# ![4%20Kasus%20Weighted%20Clustering.png](attachment:4%20Kasus%20Weighted%20Clustering.png)

# %% [markdown]
# Clustering Kasus Covid-19 : Weighted Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten, Sulawesi Selatan, Jawa Tengah, Jawa Timur, Jawa Barat
#
# Cluster 3 : Kalimantan Timur, Sumatera Selatan, Kalimantan Tengah, Kalimantan Utara, DI Yogyakarta, Sumatera Utara, Papua, Sumatera Barat, Kalimantan Selatan, Bali, Nusa Tenggara Barat
#
# Cluster 4 : Maluku Utara, Papua Barat, Sulawesi Utara, Jambi, Sulawesi Barat, Riau, Sulawesi Tenggara, Lampung, Sulawesi Tengah, Kalimantan Barat, Kepulauan Riau, Nusa Tenggara Timur, Bengkulu, Aceh, Gorontalo, Bangka Belitung, Maluku

# %% [markdown]
# # 5. Ward Linkage

# %% [markdown]
# ![5%20Faktor%20Ward%20Clustering.png](attachment:5%20Faktor%20Ward%20Clustering.png)

# %% [markdown]
# Clustering Faktor Covid-19 : Ward Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Jawa Timur, Jawa Tengah, Jawa Barat, Banten
#
# Cluster 3 : Lampung, Sumatera Selatan, Sumatera Utara, Maluku, Kalimantan Timur, Kep. Bangka Belitung, Kalimantan Barat, Aceh, Nusa Tenggara Timur, Nusa Tenggara Barat, Kalimantan Selatan, Sumatera Barat, Gorontalo, Bengkulu, Sulawesi Tengah, Sulawesi Barat, Sulawesi Tenggara, Maluku Utara, Kalimantan Utara, Papua, Kep. Riau, Papua Barat, Riau, Jambi, Kalimantan Tengah
#
# Cluster 4 : Bali, Sulawesi Selatan, Sulawesi Utara, DI Yogyakarta

# %% [markdown]
# ![5%20Kasus%20Ward%20Clustering.png](attachment:5%20Kasus%20Ward%20Clustering.png)

# %% [markdown]
# Clustering Kasus Covid-19 : Ward Linkage
#
# Cluster 1 : DKI Jakarta
#
# Cluster 2 : Banten, Sulawesi Selatan, Jawa Tengah, Jawa Timur, Jawa Barat
#
# Cluster 3 : Kalimantan Timur, Sumatera Selatan, Kalimantan Tengah, Kalimantan Utara, DI Yogyakarta, Sumatera Utara, Papua, Sumatera Barat, Kalimantan Selatan, Bali, Nusa Tenggara Barat
#
# Cluster 4 : Riau, Sulawesi Tenggara, Lampung, Sulawesi Tengah, Sulawesi Barat, Maluku Utara, Papua Barat, Sulawesi Utara, Jambi, Kalimantan Barat, Kepulauan Riau, Nusa Tenggara Timur, Bengkulu, Aceh, Gorontalo, Bangka Belitung, Maluku

# %% [markdown]
# # Analisis Evaluasi

# %% [markdown]
# Confusion matrix metode Single Linkage :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kemudian dihitung :<br>
# 1. Akurasi : 1/34 = 0,0294<br>
# 2. Presisi = 1/34 = 0,0294<br>
# 3. Recall = 1/1 = 1<br>
# 4. Error rate = 33/34 = 0,9706

# %% [markdown]
# Confusion matrix metode Complete Linkage :

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kemudian dihitung :<br>
# 1. Akurasi : 15/34 = 0,4412<br>
# 2. Presisi = 15/34 = 0,4412<br>
# 3. Recall = 1/1 = 1<br>
# 4. Error rate = 19/34 = 0,5588

# %% [markdown]
# Confusion matrix metode Average Linkage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kemudian dihitung :<br>
# 1. Akurasi :32/34 = 0,9412<br>
# 2. Presisi : 32/34 = 0,9412<br>
# 3. Recall : 32/32 = 1<br>
# 4. Error rate : 2/34 = 0,0588

# %% [markdown]
# Confusion matrix metode Weighted Linkage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kemudian dihitung :
# 1. Akurasi :2/34 = 0,0588<br>
# 2. Presisi : 2/34 = 0,0588<br>
# 3. Recall : 2/2 = 1<br>
# 4. Error rate : 32/34 = 0,9412

# %% [markdown]
# Confusion matrix metode Ward Linkage

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Kemudian dihitung :<br>
# 1. Akurasi :15/34 = 0,4412<br>
# 2. Presisi : 15/34 = 0,4412<br>
# 3. Recall : 15/15 = 1<br>
# 4. Error rate : 19/34 = 0,5588

# %% [markdown]
# # Analisis Karateristik Cluster

# %% [markdown]
# Klasterisasi menggunakan metode Single Linkage & Average Lingkage menghasilkan cluster yang sama, yaitu: cluster 1 hanya terdapat satu provinsi saja yaitu DKI Jakarta yang dengan tingkat kerawanan COVID-19 tertinggi; tertinggi kedua adalah cluster 4 yitu Jawa Timur dan Jawa Barat; cluster 2 yaitu provinsi Banten, Sulawesi Selatan, dan Jawa Tengah merupakan provinsi-provinsi dengan tingkat kerawanan sedang karena rata-rata jumlah kasus COVID-19 lebih banyak dari cluster 3 dan lebih rendah dari cluster 1 dan 4, sedangkan tingkat kerawanan rendah adalah cluster 3 dengan anggota terbanyak yaitu 28 provinsi.
#
# Klasterisasi menggunakan metode Complete Linkage, Weighted Linkage dan Ward's Method menghasilkan cluster yang sama: cluster 1 dengan provinsi DKI Jakarta merupakan tingkat kerawanan COVID-19 tertinggi; tertinggi kedua adalah cluster 2 yang beranggotakan provinsi Banten, Sulawesi Selatan, Jawa Tengah, Jawa Timur, dan Jawa Barat; tingkat kerawanan sedang adalah cluster 3 dengan 11 provinsi; dan terendah ialah cluster 4 dengan anggota 17 provinsi.
#
# Sedangkan, hasil yang paling akurat untuk menghitung tingkat kerawanan COVID-19 di Indonesia berdasarkan provinsi adalah dengan menggunakan metode Average Linkage yang berdasar pada jumlah kasus positif COVID-19 dengan faktor-faktor: jumlah penduduk, kepadatan penduduk, kualitas udara, persentase penduduk lanjut usia, jumlah penduduk memiliki JKN, tingkat akses ke sanitasi yang aman, serta jumlah penumpang pesawat. Tingkat kerawanan COVID-19 terendah adalah cluster 4 yang beranggotakan 17 provinsi, ditunjukkan oleh rata-rata jumlah penduduk, persentase kepadatan penduduk, dan jumlah penumpang pesawat yang paling rendah diantara cluster lainnya, serta memiliki kualitas udara paling tinggi dari anggota cluster lainnya.

# %% [markdown]
# # Summarize

# %% [markdown]
# Sistem akan menggunakan beberapa parameter yaitu :<br>
# - Parameter Jumlah Penduduk<br>
# - Parameter Kepadatan Penduduk<br>
# - Parameter Kualitas Udara<br>
# - Parameter Jumlah Penduduk Lanjut Usia<br>
# - Parameter Jumlah Penumpang Pesawat<br>
# <br>

# %% [markdown]
# # Beberapa Teori Pendukung

# %% [markdown]
# Pada penelitian sebelumnya telah dibahas mengenai Perbandingan Metode Clustering Menggunakan Metode Single Linkage dan K - MEANS Pada Pengelompokan Dokumen. Penelitian tersebut di lakukan oleh Rendy Handoyo dan teman-temannya pada tahun 2014. Pada penelitian itu dihasilkan sebuah kesimpulan bahwa metode Single Linkage memiliki performansi yang lebih baik dibandingkan dengan metode K-means. Metode pengujian yang digunakan untuk mengukur kualitas cluster adalah Silhouette Coefficient dan Purity. Nilai Silhouette Coefficient Single Linkage selalu lebih unggul dibandingkan dengan K-Means. Pertambahan jumlah dokumen membuat nilai Silhouette Coefficient single linkage semakin kecil sedangkan K-means terkadang menghasilkan nilai yang negatif. Untuk nilai Purity , Single Linkage selalu bernilai 1 sedangkan K-Means tidak pernah bernilai 1. Hasil pertambahan jumlah cluster dan jumlah dokumen memberikan pengaruh terhadap nilai Silhouette Coefficient dan Purity . Hal ini berarti single linkage selalu menghasilkan dokumen yang sama, sedangkan K-means masih bercampur dengan dokumen yang lain.<br>
# <br>
# Berdasarkan Analisis Karateristik Cluster, yang menggunakan metode Single Linkage & Average Lingkage menghasilkan cluster yang sama, yaitu: cluster 1.<br>
# Sedangkan  metode Complete Linkage, Weighted Linkage dan Ward's Method menghasilkan cluster yang sama: cluster 1.<br>
# Sementara, hasil terakurat untuk menghitung tingkat kerawanan COVID-19 di Indonesia berdasarkan provinsi adalah dengan menggunakan metode Average Linkage.<br>
# <br>
